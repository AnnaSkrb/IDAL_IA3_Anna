# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaSkrb/IDAL_IA3_Anna/blob/main/dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %%
X_train.shape
# Out:
# (60000, 784)

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (784)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model = tf.keras.models.Sequential()
model.add(Dense(units=256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 1s 4ms/step - loss: 0.5072 - accuracy: 0.8422 - val_loss: 0.2115 - val_accuracy: 0.9373
# Epoch 2/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1556 - accuracy: 0.9548 - val_loss: 0.1399 - val_accuracy: 0.9589
# Epoch 3/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9681 - val_loss: 0.1012 - val_accuracy: 0.9705
# Epoch 4/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9755 - val_loss: 0.0999 - val_accuracy: 0.9694
# Epoch 5/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9807 - val_loss: 0.0902 - val_accuracy: 0.9720
# Epoch 6/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9841 - val_loss: 0.0799 - val_accuracy: 0.9760
# Epoch 7/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 0.9878 - val_loss: 0.0786 - val_accuracy: 0.9766
# Epoch 8/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9904 - val_loss: 0.0857 - val_accuracy: 0.9749
# Epoch 9/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9921 - val_loss: 0.0791 - val_accuracy: 0.9774
# Epoch 10/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9931 - val_loss: 0.0743 - val_accuracy: 0.9790
# Epoch 11/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.0753 - val_accuracy: 0.9791
# Epoch 12/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0741 - val_accuracy: 0.9807
# Epoch 13/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0792 - val_accuracy: 0.9781
# Epoch 14/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0853 - val_accuracy: 0.9789
# Epoch 15/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.0960 - val_accuracy: 0.9765
# Epoch 16/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.1008 - val_accuracy: 0.9751
# Epoch 17/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.0903 - val_accuracy: 0.9791
# Epoch 18/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0855 - val_accuracy: 0.9799
# Epoch 19/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.0880 - val_accuracy: 0.9805
# Epoch 20/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0944 - val_accuracy: 0.9779
# Epoch 21/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0891 - val_accuracy: 0.9800
# Epoch 22/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0840 - val_accuracy: 0.9821
# Epoch 23/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.1018 - val_accuracy: 0.9785
# Epoch 24/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0919 - val_accuracy: 0.9816
# Epoch 25/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.1087 - val_accuracy: 0.9760
# Epoch 26/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0995 - val_accuracy: 0.9789
# Epoch 27/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.1072 - val_accuracy: 0.9781
# Epoch 28/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.1128 - val_accuracy: 0.9763
# Epoch 29/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.1091 - val_accuracy: 0.9779
# Epoch 30/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.1016 - val_accuracy: 0.9784
# Epoch 31/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0957 - val_accuracy: 0.9810
# Epoch 32/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0955 - val_accuracy: 0.9829
# Epoch 33/35
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0937 - val_accuracy: 0.9820
# Epoch 34/35
# 118/118 [==============================] - 0s 3ms/step - loss: 5.3495e-04 - accuracy: 0.9999 - val_loss: 0.1032 - val_accuracy: 0.9806
# Epoch 35/35
# 118/118 [==============================] - 0s 3ms/step - loss: 1.7636e-04 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9823

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
tf.keras.backend.clear_session()
n_epochs = 50
reg = 0.01

# Crear modelo
model_with_l2 = tf.keras.models.Sequential()
model_with_l2.add(Dense(units=256, activation='relu', input_shape=(X_train.shape[1],), kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(reg)))
model_with_l2.add(Dense(10, activation='softmax'))

# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 1s 5ms/step - loss: 1.6273 - accuracy: 0.8349 - val_loss: 0.8714 - val_accuracy: 0.9023
# Epoch 2/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.7970 - accuracy: 0.9145 - val_loss: 0.7424 - val_accuracy: 0.9192
# Epoch 3/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.7022 - accuracy: 0.9276 - val_loss: 0.6685 - val_accuracy: 0.9300
# Epoch 4/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.6538 - accuracy: 0.9342 - val_loss: 0.7259 - val_accuracy: 0.9033
# Epoch 5/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.6237 - accuracy: 0.9376 - val_loss: 0.5967 - val_accuracy: 0.9401
# Epoch 6/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.5929 - accuracy: 0.9425 - val_loss: 0.6087 - val_accuracy: 0.9286
# Epoch 7/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5764 - accuracy: 0.9431 - val_loss: 0.5577 - val_accuracy: 0.9458
# Epoch 8/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5565 - accuracy: 0.9464 - val_loss: 0.5929 - val_accuracy: 0.9326
# Epoch 9/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.5506 - accuracy: 0.9451 - val_loss: 0.5338 - val_accuracy: 0.9474
# Epoch 10/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5337 - accuracy: 0.9480 - val_loss: 0.5169 - val_accuracy: 0.9510
# Epoch 11/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5234 - accuracy: 0.9496 - val_loss: 0.5306 - val_accuracy: 0.9437
# Epoch 12/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.5147 - accuracy: 0.9510 - val_loss: 0.5105 - val_accuracy: 0.9498
# Epoch 13/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5045 - accuracy: 0.9518 - val_loss: 0.4971 - val_accuracy: 0.9499
# Epoch 14/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4985 - accuracy: 0.9518 - val_loss: 0.5103 - val_accuracy: 0.9451
# Epoch 15/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.4929 - accuracy: 0.9521 - val_loss: 0.4823 - val_accuracy: 0.9541
# Epoch 16/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4815 - accuracy: 0.9548 - val_loss: 0.4934 - val_accuracy: 0.9501
# Epoch 17/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4816 - accuracy: 0.9535 - val_loss: 0.4739 - val_accuracy: 0.9519
# Epoch 18/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4727 - accuracy: 0.9543 - val_loss: 0.4682 - val_accuracy: 0.9535
# Epoch 19/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4677 - accuracy: 0.9556 - val_loss: 0.4587 - val_accuracy: 0.9555
# Epoch 20/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4637 - accuracy: 0.9560 - val_loss: 0.4677 - val_accuracy: 0.9513
# Epoch 21/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4586 - accuracy: 0.9568 - val_loss: 0.4548 - val_accuracy: 0.9531
# Epoch 22/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4541 - accuracy: 0.9565 - val_loss: 0.4460 - val_accuracy: 0.9575
# Epoch 23/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4498 - accuracy: 0.9581 - val_loss: 0.4396 - val_accuracy: 0.9570
# Epoch 24/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.9579 - val_loss: 0.4381 - val_accuracy: 0.9551
# Epoch 25/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4410 - accuracy: 0.9584 - val_loss: 0.4427 - val_accuracy: 0.9561
# Epoch 26/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4364 - accuracy: 0.9589 - val_loss: 0.4427 - val_accuracy: 0.9537
# Epoch 27/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4349 - accuracy: 0.9590 - val_loss: 0.4304 - val_accuracy: 0.9562
# Epoch 28/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4300 - accuracy: 0.9594 - val_loss: 0.4308 - val_accuracy: 0.9565
# Epoch 29/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4272 - accuracy: 0.9602 - val_loss: 0.4460 - val_accuracy: 0.9492
# Epoch 30/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4252 - accuracy: 0.9594 - val_loss: 0.4292 - val_accuracy: 0.9554
# Epoch 31/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4221 - accuracy: 0.9605 - val_loss: 0.4213 - val_accuracy: 0.9573
# Epoch 32/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4192 - accuracy: 0.9601 - val_loss: 0.4200 - val_accuracy: 0.9555
# Epoch 33/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.9609 - val_loss: 0.4196 - val_accuracy: 0.9579
# Epoch 34/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4125 - accuracy: 0.9611 - val_loss: 0.4131 - val_accuracy: 0.9577
# Epoch 35/50
# 118/118 [==============================] - 0s 3ms/step - loss: 0.4118 - accuracy: 0.9607 - val_loss: 0.4226 - val_accuracy: 0.9556
# Epoch 36/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4118 - accuracy: 0.9604 - val_loss: 0.4196 - val_accuracy: 0.9554
# Epoch 37/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4058 - accuracy: 0.9621 - val_loss: 0.4203 - val_accuracy: 0.9546
# Epoch 38/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4047 - accuracy: 0.9614 - val_loss: 0.4117 - val_accuracy: 0.9572
# Epoch 39/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4049 - accuracy: 0.9609 - val_loss: 0.4026 - val_accuracy: 0.9595
# Epoch 40/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.4006 - accuracy: 0.9614 - val_loss: 0.3943 - val_accuracy: 0.9620
# Epoch 41/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3962 - accuracy: 0.9625 - val_loss: 0.3915 - val_accuracy: 0.9629
# Epoch 42/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3966 - accuracy: 0.9621 - val_loss: 0.4096 - val_accuracy: 0.9570
# Epoch 43/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3917 - accuracy: 0.9632 - val_loss: 0.3954 - val_accuracy: 0.9591
# Epoch 44/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3896 - accuracy: 0.9628 - val_loss: 0.4068 - val_accuracy: 0.9540
# Epoch 45/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3880 - accuracy: 0.9629 - val_loss: 0.3899 - val_accuracy: 0.9595
# Epoch 46/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3880 - accuracy: 0.9632 - val_loss: 0.4023 - val_accuracy: 0.9588
# Epoch 47/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3890 - accuracy: 0.9617 - val_loss: 0.3862 - val_accuracy: 0.9623
# Epoch 48/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3815 - accuracy: 0.9642 - val_loss: 0.3852 - val_accuracy: 0.9612
# Epoch 49/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3788 - accuracy: 0.9641 - val_loss: 0.3975 - val_accuracy: 0.9579
# Epoch 50/50
# 118/118 [==============================] - 0s 4ms/step - loss: 0.3798 - accuracy: 0.9642 - val_loss: 0.3830 - val_accuracy: 0.9603

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()

# Crear modelo
n_epochs = 25
dp = .2

model_with_dp = tf.keras.models.Sequential()
model_with_dp.add(Dense(units=256, activation='relu', input_shape=(X_train.shape[1],)))
model_with_dp.add(Dropout(dp))
model_with_dp.add(Dense(128, activation='relu'))
model_with_dp.add(Dropout(dp))
model_with_dp.add(Dense(64, activation='relu'))
model_with_dp.add(Dropout(dp))
model_with_dp.add(Dense(32, activation='relu'))
model_with_dp.add(Dropout(dp))
model_with_dp.add(Dense(10, activation='softmax'))

# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo
model_with_dp.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 118/118 [==============================] - 0s 4ms/step - loss: 0.5008 - accuracy: 0.8501 - val_loss: 0.1511 - val_accuracy: 0.9562
# Epoch 2/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1867 - accuracy: 0.9506 - val_loss: 0.1076 - val_accuracy: 0.9706
# Epoch 3/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9618 - val_loss: 0.1020 - val_accuracy: 0.9701
# Epoch 4/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1171 - accuracy: 0.9688 - val_loss: 0.0888 - val_accuracy: 0.9763
# Epoch 5/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9736 - val_loss: 0.0851 - val_accuracy: 0.9769
# Epoch 6/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9759 - val_loss: 0.0833 - val_accuracy: 0.9767
# Epoch 7/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9791 - val_loss: 0.0835 - val_accuracy: 0.9784
# Epoch 8/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9804 - val_loss: 0.0825 - val_accuracy: 0.9776
# Epoch 9/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0626 - accuracy: 0.9831 - val_loss: 0.0825 - val_accuracy: 0.9799
# Epoch 10/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 0.9843 - val_loss: 0.0792 - val_accuracy: 0.9808
# Epoch 11/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0562 - accuracy: 0.9848 - val_loss: 0.0814 - val_accuracy: 0.9808
# Epoch 12/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 0.9863 - val_loss: 0.0776 - val_accuracy: 0.9808
# Epoch 13/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 0.9873 - val_loss: 0.0763 - val_accuracy: 0.9828
# Epoch 14/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9881 - val_loss: 0.0865 - val_accuracy: 0.9803
# Epoch 15/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 0.9875 - val_loss: 0.0822 - val_accuracy: 0.9811
# Epoch 16/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 0.9882 - val_loss: 0.0744 - val_accuracy: 0.9822
# Epoch 17/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9895 - val_loss: 0.0836 - val_accuracy: 0.9814
# Epoch 18/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9897 - val_loss: 0.0775 - val_accuracy: 0.9832
# Epoch 19/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 0.9906 - val_loss: 0.0813 - val_accuracy: 0.9823
# Epoch 20/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 0.9906 - val_loss: 0.0830 - val_accuracy: 0.9827
# Epoch 21/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9913 - val_loss: 0.0894 - val_accuracy: 0.9814
# Epoch 22/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 0.9914 - val_loss: 0.0895 - val_accuracy: 0.9809
# Epoch 23/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9922 - val_loss: 0.0792 - val_accuracy: 0.9830
# Epoch 24/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9913 - val_loss: 0.0828 - val_accuracy: 0.9822
# Epoch 25/25
# 118/118 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9927 - val_loss: 0.0875 - val_accuracy: 0.9820

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
